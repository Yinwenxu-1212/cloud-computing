# %%
import pandas as pd
import matplotlib.pyplot as plt
import random as rnd

# %%
df_demand = pd.read_csv('demand.csv')

# %%
df_demand.head()
# Out:
#               mtime     A     B     C     D     E      F     G    H      I  \
# 0  2021-10-01T00:00  6846  7693  2682  4918  3185  16566  3822  944  13051
# 1  2021-10-01T00:05  6558  7648  2628  4631  2858  15487  3513  904  12084
# 2  2021-10-01T00:10  6038  7279  2428  4316  2574  15166  3306  814  11115
# 3  2021-10-01T00:15  6721  8089  2453  4236  2427  17347  3312  851  12102
# 4  2021-10-01T00:20  5565  7058  2072  3730  2245  14682  2903  821   9775
#
#    ...      V     W      X     Y     Z     a     b     c    d     e
# 0  ...  11599  2713  14148  1061  7785  6577  6774  8694  641  4405
# 1  ...  10986  2637  13645  1152  7428  6112  6464  8288  640  4051
# 2  ...  10303  2504  13097  2413  7056  5740  6081  7966  556  3771
# 3  ...  11434  2586  14473  2798  8118  5764  7382  8785  603  3718
# 4  ...   9748  2437  12382  4016  7234  5312  6162  7968  591  3423
#
# [5 rows x 32 columns]

# %%
plt.plot(df_demand['A'][:288])

# %%
plt.plot(df_demand['A']*rnd.randrange(20,500,1)/100)

# %%
max(df_demand['B']*rnd.randrange(80,500,5)/100)
# Out:
# 133948.5

# %%
max(df_demand['B'])
# Out:
# 63785
